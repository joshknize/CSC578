# %%
import os
os.chdir('/home/jknize/main/repo/CSC578/detectron2')

# %% [markdown]
# Simple ResNet object detection evaluation using pre-trained backbone

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("my_val_dataset", {}, "../datasets/coco/annotations/filtered_instances_val2017.json", "../datasets/coco/val2017")
register_coco_instances("full_train_dataset2", {}, "../datasets/coco/annotations/instances_train2017.json", "../datasets/coco/train2017")
# register_coco_instances("full_val_dataset", {}, "../datasets/coco/annotations/instances_val2017.json", "../datasets/coco/val2017")

# %%
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.utils.visualizer import Visualizer
import random
import cv2
import matplotlib.pyplot as plt

my_dataset_metadata = MetadataCatalog.get("my_val_dataset")# .set(thing_classes=["person", "dog", "bottle", "chair", "book"])
dataset_dicts = DatasetCatalog.get("my_val_dataset")

# Visualize 3 random images
for d in random.sample(dataset_dicts, 3):
    file_name = d['file_name']
    img = cv2.imread(d["file_name"]) 
    if img is None:
        print(f"Failed to load image: {d['file_name']}")
        continue 
     
    visualizer = Visualizer(img[:, :, ::-1], metadata=my_dataset_metadata, scale=0.5)
    out = visualizer.draw_dataset_dict(d)  # Draw annotations on the image
    output_image = out.get_image()[:, :, ::-1]  # Convert back from BGR to RGB for matplotlib
    plt.imshow(output_image)
    plt.axis("off")  # Turn off axis
    plt.show()
# Out:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.

# %%
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer, DefaultPredictor
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader

# load simple ResNet-50 model without FPN
cfg = get_cfg()
cfg.merge_from_file("configs/COCO-Detection/faster_rcnn_R_50_C4_1x.yaml")
# use COCO-pretrained detection weights for quick evaluation
cfg.MODEL.WEIGHTS = "../../../model_final_721ade.pkl" # downloaded from detectron2 MODEL_ZOO.md
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5 

cfg.DATASETS.TRAIN = ("full_train_dataset2",)
cfg.DATASETS.TEST = ("my_val_dataset",)
# cfg.MODEL.ROI_HEADS.NUM_CLASSES = 5

predictor = DefaultPredictor(cfg)

trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
evaluator = COCOEvaluator("my_val_dataset", cfg, False, output_dir="./knize/output/subset")
results = trainer.test(cfg, model=trainer.model, evaluators=[evaluator])
print("Evaluation Results:")
for key, value in results.items():
    print(f"{key}: {value}")

# when only change is filtered_annotations, predictions are made on dataset not within subset classes -> error
# Out:
# [11/10 07:36:36 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): ResNet(
#     (stem): BasicStem(
#       (conv1): Conv2d(
#         3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#         (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#       )
#     )
#     (res2): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#       )
#     )
#     (res3): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#       )
#     )
#     (res4): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (3): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (4): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(1024, 15, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(1024, 60, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): Res5ROIHeads(
#     (pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#       )
#     )
#     (res5): Sequential(
#       (0): BottleneckBlock(
#         (shortcut): Conv2d(
#           1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#         (conv1): Conv2d(
#           1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (1): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#       (2): BottleneckBlock(
#         (conv1): Conv2d(
#           2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv2): Conv2d(
#           512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#         )
#         (conv3): Conv2d(
#           512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#         )
#       )
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=2048, out_features=81, bias=True)
#       (bbox_pred): Linear(in_features=2048, out_features=320, bias=True)
#     )
#   )
# )
# [11/10 07:36:53 d2.data.datasets.coco]: Loading ../datasets/coco/annotations/instances_train2017.json takes 17.10 seconds.
# WARNING [11/10 07:36:53 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/10 07:36:54 d2.data.datasets.coco]: Loaded 118287 images in COCO format from ../datasets/coco/annotations/instances_train2017.json
# [11/10 07:37:02 d2.data.build]: Removed 1021 images with no usable annotations. 117266 images left.
# [11/10 07:37:05 d2.data.build]: Distribution of instances among all 80 categories:
# |   category    | #instances   |   category   | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:------------:|:-------------|:-------------:|:-------------|
# |    person     | 257253       |   bicycle    | 7056         |      car      | 43533        |
# |  motorcycle   | 8654         |   airplane   | 5129         |      bus      | 6061         |
# |     train     | 4570         |    truck     | 9970         |     boat      | 10576        |
# | traffic light | 12842        | fire hydrant | 1865         |   stop sign   | 1983         |
# | parking meter | 1283         |    bench     | 9820         |     bird      | 10542        |
# |      cat      | 4766         |     dog      | 5500         |     horse     | 6567         |
# |     sheep     | 9223         |     cow      | 8014         |   elephant    | 5484         |
# |     bear      | 1294         |    zebra     | 5269         |    giraffe    | 5128         |
# |   backpack    | 8714         |   umbrella   | 11265        |    handbag    | 12342        |
# |      tie      | 6448         |   suitcase   | 6112         |    frisbee    | 2681         |
# |     skis      | 6623         |  snowboard   | 2681         |  sports ball  | 6299         |
# |     kite      | 8802         | baseball bat | 3273         | baseball gl.. | 3747         |
# |  skateboard   | 5536         |  surfboard   | 6095         | tennis racket | 4807         |
# |    bottle     | 24070        |  wine glass  | 7839         |      cup      | 20574        |
# |     fork      | 5474         |    knife     | 7760         |     spoon     | 6159         |
# |     bowl      | 14323        |    banana    | 9195         |     apple     | 5776         |
# |   sandwich    | 4356         |    orange    | 6302         |   broccoli    | 7261         |
# |    carrot     | 7758         |   hot dog    | 2884         |     pizza     | 5807         |
# |     donut     | 7005         |     cake     | 6296         |     chair     | 38073        |
# |     couch     | 5779         | potted plant | 8631         |      bed      | 4192         |
# | dining table  | 15695        |    toilet    | 4149         |      tv       | 5803         |
# |    laptop     | 4960         |    mouse     | 2261         |    remote     | 5700         |
# |   keyboard    | 2854         |  cell phone  | 6422         |   microwave   | 1672         |
# |     oven      | 3334         |   toaster    | 225          |     sink      | 5609         |
# | refrigerator  | 2634         |     book     | 24077        |     clock     | 6320         |
# |     vase      | 6577         |   scissors   | 1464         |  teddy bear   | 4729         |
# |  hair drier   | 198          |  toothbrush  | 1945         |               |              |
# |     total     | 849949       |              |              |               |              |
# [11/10 07:37:05 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [11/10 07:37:05 d2.data.build]: Using training sampler TrainingSampler
# [11/10 07:37:05 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [11/10 07:37:05 d2.data.common]: Serializing 117266 elements to byte tensors and concatenating them all ...
# [11/10 07:37:08 d2.data.common]: Serialized dataset takes 451.55 MiB
# [11/10 07:37:08 d2.data.build]: Making batched data loader with batch_size=16
# [11/10 07:37:10 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ../../../model_final_721ade.pkl ...
# [11/10 07:37:10 d2.evaluation.coco_evaluation]: Fast COCO eval is not built. Falling back to official COCO eval.
# WARNING [11/10 07:37:10 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# WARNING [11/10 07:37:10 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [11/10 07:37:10 d2.data.datasets.coco]: Loaded 5000 images in COCO format from ../datasets/coco/annotations/filtered_instances_val2017.json
# [11/10 07:37:11 d2.data.build]: Distribution of instances among all 5 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   person   | 10777        |    dog     | 218          |   bottle   | 1013         |
# |   chair    | 1771         |    book    | 1129         |            |              |
# |   total    | 14908        |            |              |            |              |
# [11/10 07:37:11 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [11/10 07:37:11 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [11/10 07:37:11 d2.data.common]: Serializing 5000 elements to byte tensors and concatenating them all ...
# [11/10 07:37:11 d2.data.common]: Serialized dataset takes 9.41 MiB
# [11/10 07:37:11 d2.evaluation.evaluator]: Start inference on 5000 batches
# /home/jknize/.local/lib/python3.8/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [11/10 07:37:13 d2.evaluation.evaluator]: Inference done 11/5000. Dataloading: 0.0009 s/iter. Inference: 0.1470 s/iter. Eval: 0.0003 s/iter. Total: 0.1482 s/iter. ETA=0:12:19
# [11/10 07:37:18 d2.evaluation.evaluator]: Inference done 60/5000. Dataloading: 0.0014 s/iter. Inference: 0.1055 s/iter. Eval: 0.0003 s/iter. Total: 0.1073 s/iter. ETA=0:08:49
# [11/10 07:37:23 d2.evaluation.evaluator]: Inference done 114/5000. Dataloading: 0.0014 s/iter. Inference: 0.0988 s/iter. Eval: 0.0003 s/iter. Total: 0.1006 s/iter. ETA=0:08:11
# [11/10 07:37:28 d2.evaluation.evaluator]: Inference done 166/5000. Dataloading: 0.0014 s/iter. Inference: 0.0977 s/iter. Eval: 0.0003 s/iter. Total: 0.0995 s/iter. ETA=0:08:00
# [11/10 07:37:33 d2.evaluation.evaluator]: Inference done 217/5000. Dataloading: 0.0014 s/iter. Inference: 0.0975 s/iter. Eval: 0.0003 s/iter. Total: 0.0993 s/iter. ETA=0:07:54
# [11/10 07:37:38 d2.evaluation.evaluator]: Inference done 269/5000. Dataloading: 0.0014 s/iter. Inference: 0.0970 s/iter. Eval: 0.0003 s/iter. Total: 0.0988 s/iter. ETA=0:07:47
# [11/10 07:37:43 d2.evaluation.evaluator]: Inference done 320/5000. Dataloading: 0.0014 s/iter. Inference: 0.0969 s/iter. Eval: 0.0003 s/iter. Total: 0.0987 s/iter. ETA=0:07:42
# [11/10 07:37:48 d2.evaluation.evaluator]: Inference done 367/5000. Dataloading: 0.0014 s/iter. Inference: 0.0979 s/iter. Eval: 0.0003 s/iter. Total: 0.0998 s/iter. ETA=0:07:42
# [11/10 07:37:54 d2.evaluation.evaluator]: Inference done 417/5000. Dataloading: 0.0014 s/iter. Inference: 0.0981 s/iter. Eval: 0.0003 s/iter. Total: 0.1000 s/iter. ETA=0:07:38
# [11/10 07:37:59 d2.evaluation.evaluator]: Inference done 465/5000. Dataloading: 0.0014 s/iter. Inference: 0.0987 s/iter. Eval: 0.0003 s/iter. Total: 0.1006 s/iter. ETA=0:07:36
# [11/10 07:38:04 d2.evaluation.evaluator]: Inference done 512/5000. Dataloading: 0.0014 s/iter. Inference: 0.0994 s/iter. Eval: 0.0003 s/iter. Total: 0.1012 s/iter. ETA=0:07:34
# [11/10 07:38:09 d2.evaluation.evaluator]: Inference done 558/5000. Dataloading: 0.0014 s/iter. Inference: 0.1001 s/iter. Eval: 0.0003 s/iter. Total: 0.1020 s/iter. ETA=0:07:32
# [11/10 07:38:14 d2.evaluation.evaluator]: Inference done 607/5000. Dataloading: 0.0014 s/iter. Inference: 0.1002 s/iter. Eval: 0.0003 s/iter. Total: 0.1020 s/iter. ETA=0:07:28
# [11/10 07:38:19 d2.evaluation.evaluator]: Inference done 655/5000. Dataloading: 0.0014 s/iter. Inference: 0.1004 s/iter. Eval: 0.0003 s/iter. Total: 0.1022 s/iter. ETA=0:07:24
# [11/10 07:38:24 d2.evaluation.evaluator]: Inference done 703/5000. Dataloading: 0.0014 s/iter. Inference: 0.1005 s/iter. Eval: 0.0003 s/iter. Total: 0.1024 s/iter. ETA=0:07:19
# [11/10 07:38:29 d2.evaluation.evaluator]: Inference done 747/5000. Dataloading: 0.0014 s/iter. Inference: 0.1013 s/iter. Eval: 0.0003 s/iter. Total: 0.1031 s/iter. ETA=0:07:18
# [11/10 07:38:34 d2.evaluation.evaluator]: Inference done 793/5000. Dataloading: 0.0014 s/iter. Inference: 0.1017 s/iter. Eval: 0.0003 s/iter. Total: 0.1035 s/iter. ETA=0:07:15
# [11/10 07:38:39 d2.evaluation.evaluator]: Inference done 837/5000. Dataloading: 0.0015 s/iter. Inference: 0.1023 s/iter. Eval: 0.0003 s/iter. Total: 0.1041 s/iter. ETA=0:07:13
# [11/10 07:38:44 d2.evaluation.evaluator]: Inference done 882/5000. Dataloading: 0.0015 s/iter. Inference: 0.1027 s/iter. Eval: 0.0003 s/iter. Total: 0.1045 s/iter. ETA=0:07:10
# [11/10 07:38:49 d2.evaluation.evaluator]: Inference done 928/5000. Dataloading: 0.0015 s/iter. Inference: 0.1030 s/iter. Eval: 0.0003 s/iter. Total: 0.1048 s/iter. ETA=0:07:06
# [11/10 07:38:54 d2.evaluation.evaluator]: Inference done 974/5000. Dataloading: 0.0015 s/iter. Inference: 0.1032 s/iter. Eval: 0.0003 s/iter. Total: 0.1050 s/iter. ETA=0:07:02
# [11/10 07:38:59 d2.evaluation.evaluator]: Inference done 1019/5000. Dataloading: 0.0015 s/iter. Inference: 0.1034 s/iter. Eval: 0.0003 s/iter. Total: 0.1053 s/iter. ETA=0:06:59
# [11/10 07:39:04 d2.evaluation.evaluator]: Inference done 1064/5000. Dataloading: 0.0015 s/iter. Inference: 0.1037 s/iter. Eval: 0.0003 s/iter. Total: 0.1056 s/iter. ETA=0:06:55
# [11/10 07:39:09 d2.evaluation.evaluator]: Inference done 1107/5000. Dataloading: 0.0015 s/iter. Inference: 0.1041 s/iter. Eval: 0.0003 s/iter. Total: 0.1060 s/iter. ETA=0:06:52
# [11/10 07:39:14 d2.evaluation.evaluator]: Inference done 1153/5000. Dataloading: 0.0015 s/iter. Inference: 0.1044 s/iter. Eval: 0.0003 s/iter. Total: 0.1062 s/iter. ETA=0:06:48
# [11/10 07:39:19 d2.evaluation.evaluator]: Inference done 1197/5000. Dataloading: 0.0015 s/iter. Inference: 0.1047 s/iter. Eval: 0.0003 s/iter. Total: 0.1065 s/iter. ETA=0:06:45
# [11/10 07:39:24 d2.evaluation.evaluator]: Inference done 1241/5000. Dataloading: 0.0015 s/iter. Inference: 0.1050 s/iter. Eval: 0.0003 s/iter. Total: 0.1068 s/iter. ETA=0:06:41
# [11/10 07:39:29 d2.evaluation.evaluator]: Inference done 1283/5000. Dataloading: 0.0015 s/iter. Inference: 0.1055 s/iter. Eval: 0.0003 s/iter. Total: 0.1073 s/iter. ETA=0:06:38
# [11/10 07:39:35 d2.evaluation.evaluator]: Inference done 1326/5000. Dataloading: 0.0015 s/iter. Inference: 0.1058 s/iter. Eval: 0.0003 s/iter. Total: 0.1077 s/iter. ETA=0:06:35
# [11/10 07:39:40 d2.evaluation.evaluator]: Inference done 1372/5000. Dataloading: 0.0015 s/iter. Inference: 0.1059 s/iter. Eval: 0.0003 s/iter. Total: 0.1078 s/iter. ETA=0:06:31
# [11/10 07:39:45 d2.evaluation.evaluator]: Inference done 1416/5000. Dataloading: 0.0015 s/iter. Inference: 0.1061 s/iter. Eval: 0.0003 s/iter. Total: 0.1080 s/iter. ETA=0:06:27
# [11/10 07:39:50 d2.evaluation.evaluator]: Inference done 1458/5000. Dataloading: 0.0015 s/iter. Inference: 0.1065 s/iter. Eval: 0.0003 s/iter. Total: 0.1083 s/iter. ETA=0:06:23
# [11/10 07:39:55 d2.evaluation.evaluator]: Inference done 1503/5000. Dataloading: 0.0015 s/iter. Inference: 0.1066 s/iter. Eval: 0.0003 s/iter. Total: 0.1085 s/iter. ETA=0:06:19
# [11/10 07:40:00 d2.evaluation.evaluator]: Inference done 1545/5000. Dataloading: 0.0015 s/iter. Inference: 0.1070 s/iter. Eval: 0.0003 s/iter. Total: 0.1089 s/iter. ETA=0:06:16
# [11/10 07:40:05 d2.evaluation.evaluator]: Inference done 1586/5000. Dataloading: 0.0015 s/iter. Inference: 0.1073 s/iter. Eval: 0.0003 s/iter. Total: 0.1092 s/iter. ETA=0:06:12
# [11/10 07:40:10 d2.evaluation.evaluator]: Inference done 1628/5000. Dataloading: 0.0015 s/iter. Inference: 0.1076 s/iter. Eval: 0.0003 s/iter. Total: 0.1095 s/iter. ETA=0:06:09
# [11/10 07:40:15 d2.evaluation.evaluator]: Inference done 1672/5000. Dataloading: 0.0015 s/iter. Inference: 0.1078 s/iter. Eval: 0.0003 s/iter. Total: 0.1097 s/iter. ETA=0:06:05
# [11/10 07:40:20 d2.evaluation.evaluator]: Inference done 1713/5000. Dataloading: 0.0015 s/iter. Inference: 0.1082 s/iter. Eval: 0.0003 s/iter. Total: 0.1101 s/iter. ETA=0:06:01
# [11/10 07:40:25 d2.evaluation.evaluator]: Inference done 1755/5000. Dataloading: 0.0015 s/iter. Inference: 0.1084 s/iter. Eval: 0.0003 s/iter. Total: 0.1103 s/iter. ETA=0:05:58
# [11/10 07:40:30 d2.evaluation.evaluator]: Inference done 1797/5000. Dataloading: 0.0015 s/iter. Inference: 0.1087 s/iter. Eval: 0.0003 s/iter. Total: 0.1106 s/iter. ETA=0:05:54
# [11/10 07:40:36 d2.evaluation.evaluator]: Inference done 1840/5000. Dataloading: 0.0015 s/iter. Inference: 0.1088 s/iter. Eval: 0.0003 s/iter. Total: 0.1107 s/iter. ETA=0:05:49
# [11/10 07:40:41 d2.evaluation.evaluator]: Inference done 1880/5000. Dataloading: 0.0015 s/iter. Inference: 0.1092 s/iter. Eval: 0.0003 s/iter. Total: 0.1111 s/iter. ETA=0:05:46
# [11/10 07:40:46 d2.evaluation.evaluator]: Inference done 1922/5000. Dataloading: 0.0015 s/iter. Inference: 0.1094 s/iter. Eval: 0.0003 s/iter. Total: 0.1113 s/iter. ETA=0:05:42
# [11/10 07:40:51 d2.evaluation.evaluator]: Inference done 1966/5000. Dataloading: 0.0015 s/iter. Inference: 0.1095 s/iter. Eval: 0.0003 s/iter. Total: 0.1114 s/iter. ETA=0:05:38
# [11/10 07:40:56 d2.evaluation.evaluator]: Inference done 2009/5000. Dataloading: 0.0015 s/iter. Inference: 0.1097 s/iter. Eval: 0.0003 s/iter. Total: 0.1116 s/iter. ETA=0:05:33
# [11/10 07:41:01 d2.evaluation.evaluator]: Inference done 2050/5000. Dataloading: 0.0015 s/iter. Inference: 0.1099 s/iter. Eval: 0.0003 s/iter. Total: 0.1118 s/iter. ETA=0:05:29
# [11/10 07:41:06 d2.evaluation.evaluator]: Inference done 2093/5000. Dataloading: 0.0015 s/iter. Inference: 0.1100 s/iter. Eval: 0.0003 s/iter. Total: 0.1119 s/iter. ETA=0:05:25
# [11/10 07:41:11 d2.evaluation.evaluator]: Inference done 2134/5000. Dataloading: 0.0015 s/iter. Inference: 0.1103 s/iter. Eval: 0.0003 s/iter. Total: 0.1122 s/iter. ETA=0:05:21
# [11/10 07:41:16 d2.evaluation.evaluator]: Inference done 2175/5000. Dataloading: 0.0015 s/iter. Inference: 0.1105 s/iter. Eval: 0.0003 s/iter. Total: 0.1124 s/iter. ETA=0:05:17
# [11/10 07:41:21 d2.evaluation.evaluator]: Inference done 2216/5000. Dataloading: 0.0015 s/iter. Inference: 0.1107 s/iter. Eval: 0.0003 s/iter. Total: 0.1126 s/iter. ETA=0:05:13
# [11/10 07:41:26 d2.evaluation.evaluator]: Inference done 2256/5000. Dataloading: 0.0015 s/iter. Inference: 0.1110 s/iter. Eval: 0.0003 s/iter. Total: 0.1129 s/iter. ETA=0:05:09
# [11/10 07:41:32 d2.evaluation.evaluator]: Inference done 2296/5000. Dataloading: 0.0015 s/iter. Inference: 0.1112 s/iter. Eval: 0.0003 s/iter. Total: 0.1131 s/iter. ETA=0:05:05
# [11/10 07:41:37 d2.evaluation.evaluator]: Inference done 2337/5000. Dataloading: 0.0015 s/iter. Inference: 0.1114 s/iter. Eval: 0.0003 s/iter. Total: 0.1133 s/iter. ETA=0:05:01
# [11/10 07:41:42 d2.evaluation.evaluator]: Inference done 2379/5000. Dataloading: 0.0015 s/iter. Inference: 0.1116 s/iter. Eval: 0.0003 s/iter. Total: 0.1135 s/iter. ETA=0:04:57
# [11/10 07:41:47 d2.evaluation.evaluator]: Inference done 2419/5000. Dataloading: 0.0015 s/iter. Inference: 0.1118 s/iter. Eval: 0.0003 s/iter. Total: 0.1137 s/iter. ETA=0:04:53
# [11/10 07:41:52 d2.evaluation.evaluator]: Inference done 2461/5000. Dataloading: 0.0015 s/iter. Inference: 0.1119 s/iter. Eval: 0.0003 s/iter. Total: 0.1138 s/iter. ETA=0:04:48
# [11/10 07:41:57 d2.evaluation.evaluator]: Inference done 2504/5000. Dataloading: 0.0015 s/iter. Inference: 0.1120 s/iter. Eval: 0.0003 s/iter. Total: 0.1139 s/iter. ETA=0:04:44
# [11/10 07:42:02 d2.evaluation.evaluator]: Inference done 2545/5000. Dataloading: 0.0015 s/iter. Inference: 0.1121 s/iter. Eval: 0.0003 s/iter. Total: 0.1141 s/iter. ETA=0:04:40
# [11/10 07:42:07 d2.evaluation.evaluator]: Inference done 2586/5000. Dataloading: 0.0015 s/iter. Inference: 0.1123 s/iter. Eval: 0.0003 s/iter. Total: 0.1142 s/iter. ETA=0:04:35
# [11/10 07:42:12 d2.evaluation.evaluator]: Inference done 2626/5000. Dataloading: 0.0015 s/iter. Inference: 0.1125 s/iter. Eval: 0.0003 s/iter. Total: 0.1144 s/iter. ETA=0:04:31
# [11/10 07:42:17 d2.evaluation.evaluator]: Inference done 2664/5000. Dataloading: 0.0015 s/iter. Inference: 0.1127 s/iter. Eval: 0.0003 s/iter. Total: 0.1147 s/iter. ETA=0:04:27
# [11/10 07:42:22 d2.evaluation.evaluator]: Inference done 2707/5000. Dataloading: 0.0015 s/iter. Inference: 0.1128 s/iter. Eval: 0.0003 s/iter. Total: 0.1147 s/iter. ETA=0:04:23
# [11/10 07:42:27 d2.evaluation.evaluator]: Inference done 2744/5000. Dataloading: 0.0015 s/iter. Inference: 0.1131 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:04:19
# [11/10 07:42:33 d2.evaluation.evaluator]: Inference done 2774/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1156 s/iter. ETA=0:04:17
# [11/10 07:42:38 d2.evaluation.evaluator]: Inference done 2804/5000. Dataloading: 0.0016 s/iter. Inference: 0.1143 s/iter. Eval: 0.0003 s/iter. Total: 0.1162 s/iter. ETA=0:04:15
# [11/10 07:42:43 d2.evaluation.evaluator]: Inference done 2847/5000. Dataloading: 0.0016 s/iter. Inference: 0.1143 s/iter. Eval: 0.0003 s/iter. Total: 0.1162 s/iter. ETA=0:04:10
# [11/10 07:42:48 d2.evaluation.evaluator]: Inference done 2894/5000. Dataloading: 0.0016 s/iter. Inference: 0.1142 s/iter. Eval: 0.0003 s/iter. Total: 0.1161 s/iter. ETA=0:04:04
# [11/10 07:42:53 d2.evaluation.evaluator]: Inference done 2939/5000. Dataloading: 0.0016 s/iter. Inference: 0.1141 s/iter. Eval: 0.0003 s/iter. Total: 0.1161 s/iter. ETA=0:03:59
# [11/10 07:42:58 d2.evaluation.evaluator]: Inference done 2982/5000. Dataloading: 0.0015 s/iter. Inference: 0.1142 s/iter. Eval: 0.0003 s/iter. Total: 0.1161 s/iter. ETA=0:03:54
# [11/10 07:43:03 d2.evaluation.evaluator]: Inference done 3027/5000. Dataloading: 0.0015 s/iter. Inference: 0.1141 s/iter. Eval: 0.0003 s/iter. Total: 0.1160 s/iter. ETA=0:03:48
# [11/10 07:43:08 d2.evaluation.evaluator]: Inference done 3074/5000. Dataloading: 0.0015 s/iter. Inference: 0.1140 s/iter. Eval: 0.0003 s/iter. Total: 0.1159 s/iter. ETA=0:03:43
# [11/10 07:43:13 d2.evaluation.evaluator]: Inference done 3122/5000. Dataloading: 0.0015 s/iter. Inference: 0.1139 s/iter. Eval: 0.0003 s/iter. Total: 0.1158 s/iter. ETA=0:03:37
# [11/10 07:43:18 d2.evaluation.evaluator]: Inference done 3169/5000. Dataloading: 0.0015 s/iter. Inference: 0.1138 s/iter. Eval: 0.0003 s/iter. Total: 0.1157 s/iter. ETA=0:03:31
# [11/10 07:43:23 d2.evaluation.evaluator]: Inference done 3215/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1156 s/iter. ETA=0:03:26
# [11/10 07:43:28 d2.evaluation.evaluator]: Inference done 3257/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1156 s/iter. ETA=0:03:21
# [11/10 07:43:33 d2.evaluation.evaluator]: Inference done 3301/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1156 s/iter. ETA=0:03:16
# [11/10 07:43:39 d2.evaluation.evaluator]: Inference done 3346/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1156 s/iter. ETA=0:03:11
# [11/10 07:43:44 d2.evaluation.evaluator]: Inference done 3392/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1155 s/iter. ETA=0:03:05
# [11/10 07:43:49 d2.evaluation.evaluator]: Inference done 3436/5000. Dataloading: 0.0015 s/iter. Inference: 0.1137 s/iter. Eval: 0.0003 s/iter. Total: 0.1155 s/iter. ETA=0:03:00
# [11/10 07:43:54 d2.evaluation.evaluator]: Inference done 3485/5000. Dataloading: 0.0015 s/iter. Inference: 0.1135 s/iter. Eval: 0.0003 s/iter. Total: 0.1153 s/iter. ETA=0:02:54
# [11/10 07:43:59 d2.evaluation.evaluator]: Inference done 3531/5000. Dataloading: 0.0015 s/iter. Inference: 0.1134 s/iter. Eval: 0.0003 s/iter. Total: 0.1153 s/iter. ETA=0:02:49
# [11/10 07:44:04 d2.evaluation.evaluator]: Inference done 3575/5000. Dataloading: 0.0015 s/iter. Inference: 0.1134 s/iter. Eval: 0.0003 s/iter. Total: 0.1153 s/iter. ETA=0:02:44
# [11/10 07:44:09 d2.evaluation.evaluator]: Inference done 3620/5000. Dataloading: 0.0015 s/iter. Inference: 0.1134 s/iter. Eval: 0.0003 s/iter. Total: 0.1152 s/iter. ETA=0:02:39
# [11/10 07:44:14 d2.evaluation.evaluator]: Inference done 3668/5000. Dataloading: 0.0015 s/iter. Inference: 0.1133 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:02:33
# [11/10 07:44:19 d2.evaluation.evaluator]: Inference done 3713/5000. Dataloading: 0.0015 s/iter. Inference: 0.1133 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:02:28
# [11/10 07:44:24 d2.evaluation.evaluator]: Inference done 3761/5000. Dataloading: 0.0015 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:02:22
# [11/10 07:44:29 d2.evaluation.evaluator]: Inference done 3804/5000. Dataloading: 0.0015 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:02:17
# [11/10 07:44:34 d2.evaluation.evaluator]: Inference done 3847/5000. Dataloading: 0.0015 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:02:12
# [11/10 07:44:39 d2.evaluation.evaluator]: Inference done 3892/5000. Dataloading: 0.0015 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:02:07
# [11/10 07:44:45 d2.evaluation.evaluator]: Inference done 3937/5000. Dataloading: 0.0015 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:02:02
# [11/10 07:44:50 d2.evaluation.evaluator]: Inference done 3981/5000. Dataloading: 0.0014 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:01:57
# [11/10 07:44:55 d2.evaluation.evaluator]: Inference done 4025/5000. Dataloading: 0.0014 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:01:52
# [11/10 07:45:00 d2.evaluation.evaluator]: Inference done 4068/5000. Dataloading: 0.0014 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:01:47
# [11/10 07:45:05 d2.evaluation.evaluator]: Inference done 4112/5000. Dataloading: 0.0014 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:01:42
# [11/10 07:45:10 d2.evaluation.evaluator]: Inference done 4156/5000. Dataloading: 0.0014 s/iter. Inference: 0.1132 s/iter. Eval: 0.0003 s/iter. Total: 0.1150 s/iter. ETA=0:01:37
# [11/10 07:45:15 d2.evaluation.evaluator]: Inference done 4197/5000. Dataloading: 0.0014 s/iter. Inference: 0.1133 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:01:32
# [11/10 07:45:20 d2.evaluation.evaluator]: Inference done 4241/5000. Dataloading: 0.0014 s/iter. Inference: 0.1133 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:01:27
# [11/10 07:45:25 d2.evaluation.evaluator]: Inference done 4285/5000. Dataloading: 0.0014 s/iter. Inference: 0.1133 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:01:22
# [11/10 07:45:30 d2.evaluation.evaluator]: Inference done 4328/5000. Dataloading: 0.0014 s/iter. Inference: 0.1134 s/iter. Eval: 0.0003 s/iter. Total: 0.1151 s/iter. ETA=0:01:17
# [11/10 07:45:35 d2.evaluation.evaluator]: Inference done 4370/5000. Dataloading: 0.0014 s/iter. Inference: 0.1134 s/iter. Eval: 0.0003 s/iter. Total: 0.1152 s/iter. ETA=0:01:12
# [11/10 07:45:40 d2.evaluation.evaluator]: Inference done 4411/5000. Dataloading: 0.0014 s/iter. Inference: 0.1135 s/iter. Eval: 0.0003 s/iter. Total: 0.1153 s/iter. ETA=0:01:07
# [11/10 07:45:45 d2.evaluation.evaluator]: Inference done 4454/5000. Dataloading: 0.0014 s/iter. Inference: 0.1135 s/iter. Eval: 0.0003 s/iter. Total: 0.1153 s/iter. ETA=0:01:02
# [11/10 07:45:50 d2.evaluation.evaluator]: Inference done 4496/5000. Dataloading: 0.0014 s/iter. Inference: 0.1135 s/iter. Eval: 0.0003 s/iter. Total: 0.1153 s/iter. ETA=0:00:58
# [11/10 07:45:55 d2.evaluation.evaluator]: Inference done 4541/5000. Dataloading: 0.0014 s/iter. Inference: 0.1135 s/iter. Eval: 0.0002 s/iter. Total: 0.1153 s/iter. ETA=0:00:52
# [11/10 07:46:00 d2.evaluation.evaluator]: Inference done 4581/5000. Dataloading: 0.0014 s/iter. Inference: 0.1136 s/iter. Eval: 0.0002 s/iter. Total: 0.1154 s/iter. ETA=0:00:48
# [11/10 07:46:05 d2.evaluation.evaluator]: Inference done 4623/5000. Dataloading: 0.0014 s/iter. Inference: 0.1137 s/iter. Eval: 0.0002 s/iter. Total: 0.1155 s/iter. ETA=0:00:43
# [11/10 07:46:11 d2.evaluation.evaluator]: Inference done 4661/5000. Dataloading: 0.0014 s/iter. Inference: 0.1138 s/iter. Eval: 0.0002 s/iter. Total: 0.1156 s/iter. ETA=0:00:39
# [11/10 07:46:16 d2.evaluation.evaluator]: Inference done 4699/5000. Dataloading: 0.0014 s/iter. Inference: 0.1140 s/iter. Eval: 0.0002 s/iter. Total: 0.1157 s/iter. ETA=0:00:34
# [11/10 07:46:21 d2.evaluation.evaluator]: Inference done 4739/5000. Dataloading: 0.0014 s/iter. Inference: 0.1141 s/iter. Eval: 0.0002 s/iter. Total: 0.1158 s/iter. ETA=0:00:30
# [11/10 07:46:26 d2.evaluation.evaluator]: Inference done 4779/5000. Dataloading: 0.0014 s/iter. Inference: 0.1142 s/iter. Eval: 0.0002 s/iter. Total: 0.1159 s/iter. ETA=0:00:25
# [11/10 07:46:31 d2.evaluation.evaluator]: Inference done 4820/5000. Dataloading: 0.0014 s/iter. Inference: 0.1142 s/iter. Eval: 0.0002 s/iter. Total: 0.1160 s/iter. ETA=0:00:20
# [11/10 07:46:36 d2.evaluation.evaluator]: Inference done 4858/5000. Dataloading: 0.0014 s/iter. Inference: 0.1143 s/iter. Eval: 0.0002 s/iter. Total: 0.1161 s/iter. ETA=0:00:16
# [11/10 07:46:41 d2.evaluation.evaluator]: Inference done 4898/5000. Dataloading: 0.0014 s/iter. Inference: 0.1144 s/iter. Eval: 0.0002 s/iter. Total: 0.1162 s/iter. ETA=0:00:11
# [11/10 07:46:46 d2.evaluation.evaluator]: Inference done 4936/5000. Dataloading: 0.0014 s/iter. Inference: 0.1146 s/iter. Eval: 0.0002 s/iter. Total: 0.1163 s/iter. ETA=0:00:07
# [11/10 07:46:51 d2.evaluation.evaluator]: Inference done 4978/5000. Dataloading: 0.0014 s/iter. Inference: 0.1146 s/iter. Eval: 0.0002 s/iter. Total: 0.1164 s/iter. ETA=0:00:02
# [11/10 07:46:54 d2.evaluation.evaluator]: Total inference time: 0:09:41.639780 (0.116444 s / iter per device, on 1 devices)
# [11/10 07:46:54 d2.evaluation.evaluator]: Total inference pure compute time: 0:09:32 (0.114674 s / iter per device, on 1 devices)
# [11/10 07:46:54 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-acdc58fd8d22> in <module>
#      21 trainer.resume_or_load(resume=False)
#      22 evaluator = COCOEvaluator("my_val_dataset", cfg, False, output_dir="./knize/output/subset")
# ---> 23 results = trainer.test(cfg, model=trainer.model, evaluators=[evaluator])
#      24 print("Evaluation Results:")
#      25 for key, value in results.items():
#
# ~/main/repo/CSC578/detectron2/detectron2/engine/defaults.py in test(cls, cfg, model, evaluators)
#     651                     results[dataset_name] = {}
#     652                     continue
# --> 653             results_i = inference_on_dataset(model, data_loader, evaluator)
#     654             results[dataset_name] = results_i
#     655             if comm.is_main_process():
#
# ~/main/repo/CSC578/detectron2/detectron2/evaluation/evaluator.py in inference_on_dataset(model, data_loader, evaluator, callbacks)
#     211     )
#     212
# --> 213     results = evaluator.evaluate()
#     214     # An evaluator may return None when not in main process.
#     215     # Replace it by an empty dict instead to make it easier for downstream code to handle
#
# ~/main/repo/CSC578/detectron2/detectron2/evaluation/coco_evaluation.py in evaluate(self, img_ids)
#     204             self._eval_box_proposals(predictions)
#     205         if "instances" in predictions[0]:
# --> 206             self._eval_predictions(predictions, img_ids=img_ids)
#     207         # Copy so the caller can do whatever with results
#     208         return copy.deepcopy(self._results)
#
# ~/main/repo/CSC578/detectron2/detectron2/evaluation/coco_evaluation.py in _eval_predictions(self, predictions, img_ids)
#     238             for result in coco_results:
#     239                 category_id = result["category_id"]
# --> 240                 assert category_id < num_classes, (
#     241                     f"A prediction has class={category_id}, "
#     242                     f"but the dataset only has {num_classes} classes and "
#
# AssertionError: A prediction has class=56, but the dataset only has 5 classes and predicted class id should be in [0, 4].
